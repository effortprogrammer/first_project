# %%
import pandas as pd
import sqlalchemy

engine = sqlalchemy.create_engine('sqlite:///stock.db')

# %%
df = pd.read_sql_table('stock', engine)
df.head()
# Out:
#    id company_name  now_price
# 0   1         삼성전자      55600
# 1   2       SK하이닉스      78700
# 2   3        NAVER     328500
# 3   4         LG화학     743000
# 4   5     삼성바이오로직스     773000

# %%
# Filter
df[df.now_price > 50000]
# Out:
#     id company_name  now_price
# 0    1         삼성전자      55600
# 1    2       SK하이닉스      78700
# 2    3        NAVER     328500
# 3    4         LG화학     743000
# 4    5     삼성바이오로직스     773000
# 5    6         셀트리온     294000
# 7    8          현대차     172500
# 8    9          카카오     402000
# 9   10        삼성SDI     439000
# 10  11       LG생활건강    1453000
# 11  12        현대모비스     230000
# 12  13         삼성물산     107500
# 13  14        SK텔레콤     237500
# 14  15        엔씨소프트     813000
# 16  17          넷마블     197500
# 17  18        POSCO     186000
# 19  20           SK     212000
# 20  21       SK바이오팜     190000
# 21  22      SK이노베이션     154000
# 23  24           LG      80100
# 24  25         LG전자      84000
# 26  27         삼성생명      62200
# 27  28      삼성에스디에스     157000
# 28  29         KT&G      82700
# 29  30         삼성전기     135000
# 30  31       아모레퍼시픽     169500
# 31  32         삼성화재     182000
# 34  35         신풍제약     146000
# 35  36         고려아연     398000
# ...

# %%
# Sort

# %%
# Grouping

# %%
import csv

with open('data.csv', 'rt') as infile:
    reader = csv.DictReader(infile, fieldnames=['first', 'last'])
    villians = [row for row in reader]
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-1-157efc9800f0> in <module>
#       3 with open('data.csv', 'rt') as infile:
#       4     reader = csv.DictReader(infile, fieldnames=['first', 'last'])
# ----> 5     villians = [row for row in reader]
#
# <ipython-input-1-157efc9800f0> in <listcomp>(.0)
#       3 with open('data.csv', 'rt') as infile:
#       4     reader = csv.DictReader(infile, fieldnames=['first', 'last'])
# ----> 5     villians = [row for row in reader]
#
# ~\Conda\envs\lab\lib\csv.py in __next__(self)
#     109             # Used only for its side effect.
#     110             self.fieldnames
# --> 111         row = next(self.reader)
#     112         self.line_num = self.reader.line_num
#     113
#
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 36: illegal multibyte sequence
