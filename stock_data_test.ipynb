# %%
import numpy as np

# %%
import pandas as pd

# %%
filename = 'data.csv'
df = pd.read_csv(filename)
print(df)
# Out:
#     id company_name  now_price  profit     등락률   액면가  amount_money    상장주식수  \
# 0    1         삼성전자      55600     800 -0.0142   100       3319199  5969783
# 1    2       SK하이닉스      78700       0  0.0000  5000        572938   728002
# 2    3        NAVER     328500   10500 -0.0310   100        539605   164263
# 3    4         LG화학     743000   25000 -0.0326  5000        524501    70592
# 4    5     삼성바이오로직스     773000    6000 -0.0077  2500        511455    66165
# 5    6         셀트리온     294000    5500 -0.0184  1000        396882   134994
# 6    7        삼성전자우      47500     400 -0.0084   100        390871   822887
# 7    8          현대차     172500    4000 -0.0227  5000        368578   213668
# 8    9          카카오     402000    8000 -0.0195   500        353816    88014
# 9   10        삼성SDI     439000   13500 -0.0298  5000        301876    68765
# 10  11       LG생활건강    1453000   30000 -0.0202  5000        226932    15618
# ...

# %%
# csv file ㅡ> dict로 바꾸는 법

# %%
import csv

# %%
reader = csv.DictReader(open('data.csv'))

result = {}
for row in reader:
    key = row.pop('Date')
    if key in result:
        pass
    result[key] = row
print(result)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-18-8211db955937> in <module>
#       2
#       3 result = {}
# ----> 4 for row in reader:
#       5     key = row.pop('Date')
#       6     if key in result:
#
# ~\Conda\envs\lab\lib\csv.py in __next__(self)
#     108         if self.line_num == 0:
#     109             # Used only for its side effect.
# --> 110             self.fieldnames
#     111         row = next(self.reader)
#     112         self.line_num = self.reader.line_num
#
# ~\Conda\envs\lab\lib\csv.py in fieldnames(self)
#      95         if self._fieldnames is None:
#      96             try:
# ---> 97                 self._fieldnames = next(self.reader)
#      98             except StopIteration:
#      99                 pass
#
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 36: illegal multibyte sequence
